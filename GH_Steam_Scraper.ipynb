# %%
#Cody's Info
#Steam API Key: D055A982E240438C0651DD3B290894B3 - ISteamuserstats
#Steam ID: 76561199121994793

#Matt's Info
#Steam API Key: 8718028FBB50D15D16CE98F13624C382 - ISteamuser
#Steam ID: 76561198244049512

from google.colab import drive
drive.mount('/content/drive')

# Set your output folder
output_dir = "/content/drive/MyDrive/Data Wrangling Project/"

import os
os.makedirs(output_dir, exist_ok=True)
import os
print(f"Working directory: {os.getcwd()}")

import requests
import pandas as pd
import time

# Configuration — Matt & Cody only
users = [
    {"steam_id": "76561199121994793", "api_key": "D055A982E240438C0651DD3B290894B3", "label": "Cody"},
    {"steam_id": "76561198244049512", "api_key": "8718028FBB50D15D16CE98F13624C382", "label": "Matt"}
]

# DATA COLLECTION FUNCTIONS

def get_player_summaries(steam_ids, api_key):
    chunks = [steam_ids[i:i+100] for i in range(0, len(steam_ids), 100)]
    all_players = []
    for chunk in chunks:
        url = "http://api.steampowered.com/ISteamUser/GetPlayerSummaries/v2/"
        params = {"key": api_key, "steamids": ",".join(chunk)}
        try:
            response = requests.get(url, params=params, timeout=10)
            if response.status_code != 200 or not response.text.strip():
                continue
            players = response.json()["response"].get("players", [])
            all_players.extend(players)
        except:
            print(f"  Failed to fetch player summaries for chunk, skipping")
            continue
    df = pd.DataFrame(all_players)
    for col in ["steamid", "personaname", "loccountrycode", "timecreated"]:
        if col not in df.columns:
            df[col] = None
    df = df[["steamid", "personaname", "loccountrycode", "timecreated"]].rename(columns={
        "personaname": "username",
        "loccountrycode": "country"
    })
    return df

def get_owned_games(steam_ids, api_key):
    all_dfs = []
    url = "http://api.steampowered.com/IPlayerService/GetOwnedGames/v1/"
    for sid in steam_ids:
        params = {"key": api_key, "steamid": sid, "include_appinfo": True, "include_played_free_games": True}
        try:
            response = requests.get(url, params=params, timeout=10)
            if response.status_code != 200 or not response.text.strip():
                continue
            games = response.json()["response"].get("games", [])
            if not games:
                continue
            temp = pd.DataFrame(games)
            temp["steamid"] = sid
            all_dfs.append(temp)
        except:
            print(f"  Failed to fetch games for {sid}, skipping")
            continue
        time.sleep(0.5)
    if not all_dfs:
        return pd.DataFrame()
    df = pd.concat(all_dfs, ignore_index=True)
    df["playtime_hours"] = df["playtime_forever"] / 60
    df = df[df["playtime_hours"] > 0]
    df = df.drop(columns=["playtime_forever"])
    df = df[["steamid", "appid", "name", "playtime_hours"]]
    return df

def get_achievements(steam_ids, app_ids, api_key):
    all_dfs = []
    for sid in steam_ids:
        for appid in app_ids:
            url = "http://api.steampowered.com/ISteamUserStats/GetPlayerAchievements/v1/"
            params = {"key": api_key, "steamid": sid, "appid": appid}
            try:
                response = requests.get(url, params=params, timeout=10)
                if response.status_code != 200 or not response.text.strip():
                    continue
                stats = response.json().get("playerstats", {})
                if not stats.get("success") or "achievements" not in stats:
                    continue
                achievements = pd.DataFrame(stats["achievements"])
                completed = achievements[achievements["achieved"] == 1].shape[0]
                total = achievements.shape[0]
                all_dfs.append({"steamid": sid, "appid": appid,
                               "achievements_completed": completed, "achievements_total": total})
            except:
                continue
            time.sleep(0.5)
    if not all_dfs:
        return pd.DataFrame(columns=["steamid", "appid", "achievements_completed", "achievements_total"])
    return pd.DataFrame(all_dfs)

def get_steamspy_data(app_ids):
    all_dfs = []
    for appid in app_ids:
        url = f"https://steamspy.com/api.php?request=appdetails&appid={appid}"
        try:
            response = requests.get(url, timeout=10)
            if response.status_code != 200 or not response.text.strip():
                all_dfs.append({"appid": appid, "steamspy_name": None, "genre": None,
                    "tags": None, "owners": None, "positive_ratings": None,
                    "negative_ratings": None, "price_usd": None, "discount": None,
                    "average_playtime": None})
                time.sleep(2)
                continue
            data = response.json()
        except:
            all_dfs.append({"appid": appid, "steamspy_name": None, "genre": None,
                "tags": None, "owners": None, "positive_ratings": None,
                "negative_ratings": None, "price_usd": None, "discount": None,
                "average_playtime": None})
            time.sleep(2)
            continue

        try:
            price_usd = int(data.get("price", 0)) / 100
        except (ValueError, TypeError):
            price_usd = None

        all_dfs.append({
            "appid": appid, "steamspy_name": data.get("name"),
            "genre": data.get("genre"), "tags": data.get("tags"),
            "owners": data.get("owners"), "positive_ratings": data.get("positive"),
            "negative_ratings": data.get("negative"), "price_usd": price_usd,
            "discount": data.get("discount"), "average_playtime": data.get("average_forever")
        })
        time.sleep(1)
    return pd.DataFrame(all_dfs)

# FRIEND DISCOVERY

def get_friend_ids(steam_ids, api_key, depth=1):
    discovered = set(steam_ids)
    current_level = list(steam_ids)
    for _ in range(depth):
        next_level = []
        for sid in current_level:
            url = "http://api.steampowered.com/ISteamUser/GetFriendList/v1/"
            params = {"key": api_key, "steamid": sid, "relationship": "friend"}
            try:
                response = requests.get(url, params=params, timeout=10).json()
                friends = response.get("friendslist", {}).get("friends", [])
                for f in friends:
                    fid = f["steamid"]
                    if fid not in discovered:
                        discovered.add(fid)
                        next_level.append(fid)
            except:
                print(f"  Could not fetch friends for {sid} (private or error)")
            time.sleep(0.5)
        current_level = next_level
    discovered -= set(steam_ids)
    return list(discovered)



# BUILD RAW MASTER DATAFRAME - Seed users + 200 from friends
def build_master_df(user_list):
    all_frames = []
    for i, user in enumerate(user_list):
        sid, key, label = user["steam_id"], user["api_key"], user["label"]
        print(f"\n[{i+1}/{len(user_list)}] Pulling data for {label} ({sid[:10]}...)...")
        players_df = get_player_summaries([sid], key)
        games_df = get_owned_games([sid], key)
        if games_df.empty:
            print(f"  Skipped — no game data (private or empty)")
            continue
        app_ids = games_df["appid"].unique().tolist()
        achievements_df = get_achievements([sid], app_ids, key)
        steamspy_df = get_steamspy_data(app_ids)
        df = games_df.merge(players_df, on="steamid", how="left")
        df = df.merge(achievements_df, on=["steamid", "appid"], how="left")
        df = df.merge(steamspy_df, on="appid", how="left")
        df["label"] = label
        all_frames.append(df)

        # Save progress every 25 users
        if (i + 1) % 25 == 0 and all_frames:
            checkpoint = pd.concat(all_frames, ignore_index=True)
            checkpoint.to_csv(f"{output_dir}steam_checkpoint_{i+1}.csv", index=False)
            print(f"  ** Checkpoint saved: {checkpoint.shape[0]} rows from {i+1} users **")

    all_frames = [f for f in all_frames if not f.empty]
    return pd.concat(all_frames, ignore_index=True)

# Step 1: Discover friends
seed_ids = [u["steam_id"] for u in users]
seed_key = users[0]["api_key"]

print("Discovering friends from Matt & Cody's friend lists...")
friend_ids = get_friend_ids(seed_ids, seed_key, depth=1)
print(f"Found {len(friend_ids)} unique friends")

# Step 2: Build user list — seed users + up to 200 friends
friend_users = [
    {"steam_id": sid, "api_key": seed_key, "label": "discovered"}
    for sid in friend_ids[:200]
]

all_users = users + friend_users
print(f"Total users to pull: {len(all_users)} (2 seed + {len(friend_users)} friends)")

# Step 3: Pull everything
master_df = build_master_df(all_users)

print(f"\n{'='*60}")
print(f"RAW DATA — NO WRANGLING YET")
print(f"{'='*60}")
print(f"Shape: {master_df.shape}")
print(f"Columns: {list(master_df.columns)}")
print(f"Unique users: {master_df['steamid'].nunique()}")
print(f"Unique games: {master_df['appid'].nunique()}")
print(f"\nLabel distribution:")
print(master_df['label'].value_counts().to_string())
print(f"\nMissing values:\n{master_df.isnull().sum()}")

master_df.to_csv(f"{output_dir}steam_v1_raw.csv", index=False)
print(f"\nExported: {output_dir}steam_v1_raw.csv")


print(f"\n{'='*60}")
print(f"RAW DATA — NO WRANGLING YET")
print(f"{'='*60}")
print(f"Shape: {master_df.shape}")
print(f"Columns: {list(master_df.columns)}")
print(f"\nDtypes:\n{master_df.dtypes}")
print(f"\nMissing values:\n{master_df.isnull().sum()}")
print(f"\nFirst 3 rows:")
print(master_df.head(3).to_string())

master_df.to_csv(f"{output_dir}steam_v1_raw.csv", index=False)
print("\nExported: steam_v1_raw.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Working directory: /content
# Discovering friends from Matt & Cody's friend lists...
# Found 386 unique friends
# Total users to pull: 202 (2 seed + 200 friends)
#
# [1/202] Pulling data for Cody (7656119912...)...
#
# [2/202] Pulling data for Matt (7656119824...)...
#
# [3/202] Pulling data for discovered (7656119879...)...
#
# [4/202] Pulling data for discovered (7656119815...)...
#
# [5/202] Pulling data for discovered (7656119934...)...
#   Skipped — no game data (private or empty)
#
# [6/202] Pulling data for discovered (7656119827...)...
#
# [7/202] Pulling data for discovered (7656119807...)...
#   Skipped — no game data (private or empty)
#
# [8/202] Pulling data for discovered (7656119825...)...
#
# [9/202] Pulling data for discovered (7656119805...)...
#   Skipped — no game data (private or empty)
#
# [10/202] Pulling data for discovered (7656119814...)...
#
# [11/202] Pulling data for discovered (7656119817...)...
#   Skipped — no game data (private or empty)
#
# [12/202] Pulling data for discovered (7656119810...)...
#
# [13/202] Pulling data for discovered (7656119808...)...
#   Skipped — no game data (private or empty)
#
# [14/202] Pulling data for discovered (7656119943...)...
#
# [15/202] Pulling data for discovered (7656119826...)...
#   Skipped — no game data (private or empty)
#
# [16/202] Pulling data for discovered (7656119902...)...
#
# [17/202] Pulling data for discovered (7656119830...)...
#   Skipped — no game data (private or empty)
#
# [18/202] Pulling data for discovered (7656119805...)...
#   Skipped — no game data (private or empty)
#
# [19/202] Pulling data for discovered (7656119808...)...
#
# [20/202] Pulling data for discovered (7656119827...)...
#
# [21/202] Pulling data for discovered (7656119821...)...
#   Skipped — no game data (private or empty)
#
# [22/202] Pulling data for discovered (7656119824...)...
#   Skipped — no game data (private or empty)
#
# [23/202] Pulling data for discovered (7656119825...)...
#   Skipped — no game data (private or empty)
#
# [24/202] Pulling data for discovered (7656119820...)...
#
# [25/202] Pulling data for discovered (7656119828...)...
#   Skipped — no game data (private or empty)
#
# [26/202] Pulling data for discovered (7656119806...)...
#
# [27/202] Pulling data for discovered (7656119839...)...
#   Skipped — no game data (private or empty)
#
# [28/202] Pulling data for discovered (7656119823...)...
#   Skipped — no game data (private or empty)
#
# [29/202] Pulling data for discovered (7656119827...)...
#   Skipped — no game data (private or empty)
#
# [30/202] Pulling data for discovered (7656119828...)...
#   Skipped — no game data (private or empty)
#
# [31/202] Pulling data for discovered (7656119807...)...
#
# [32/202] Pulling data for discovered (7656119946...)...
#
# [33/202] Pulling data for discovered (7656119828...)...
#
# [34/202] Pulling data for discovered (7656119804...)...
#   Skipped — no game data (private or empty)
#
# [35/202] Pulling data for discovered (7656119837...)...
#   Skipped — no game data (private or empty)
#
# [36/202] Pulling data for discovered (7656119802...)...
#
# [37/202] Pulling data for discovered (7656119834...)...
#   Skipped — no game data (private or empty)
#
# [38/202] Pulling data for discovered (7656119814...)...
#   Skipped — no game data (private or empty)
#
# [39/202] Pulling data for discovered (7656119802...)...
#
# [40/202] Pulling data for discovered (7656119815...)...
#
# [41/202] Pulling data for discovered (7656119833...)...
#   Skipped — no game data (private or empty)
#
# [42/202] Pulling data for discovered (7656119812...)...
#
# [43/202] Pulling data for discovered (7656119809...)...
#
# [44/202] Pulling data for discovered (7656119815...)...
#
# [45/202] Pulling data for discovered (7656119824...)...
#   Skipped — no game data (private or empty)
#
# [46/202] Pulling data for discovered (7656119908...)...
#   Skipped — no game data (private or empty)
#
# [47/202] Pulling data for discovered (7656119825...)...
#
# [48/202] Pulling data for discovered (7656119826...)...
#   Skipped — no game data (private or empty)
#
# [49/202] Pulling data for discovered (7656119808...)...
#   Skipped — no game data (private or empty)
#
# [50/202] Pulling data for discovered (7656119812...)...
#   Skipped — no game data (private or empty)
#
# [51/202] Pulling data for discovered (7656119818...)...
#   Skipped — no game data (private or empty)
#
# [52/202] Pulling data for discovered (7656119824...)...
#   Skipped — no game data (private or empty)
#
# [53/202] Pulling data for discovered (7656119829...)...
#
# [54/202] Pulling data for discovered (7656119820...)...
#   Skipped — no game data (private or empty)
#
# [55/202] Pulling data for discovered (7656119816...)...
#   Skipped — no game data (private or empty)
#
# [56/202] Pulling data for discovered (7656119825...)...
#   Skipped — no game data (private or empty)
#
# [57/202] Pulling data for discovered (7656119812...)...
#   Skipped — no game data (private or empty)
#
# [58/202] Pulling data for discovered (7656119827...)...
#   Skipped — no game data (private or empty)
#
# [59/202] Pulling data for discovered (7656119827...)...
#   Skipped — no game data (private or empty)
#
# [60/202] Pulling data for discovered (7656119817...)...
#
# [61/202] Pulling data for discovered (7656119837...)...
#   Skipped — no game data (private or empty)
#
# [62/202] Pulling data for discovered (7656119830...)...
#   Skipped — no game data (private or empty)
#
# [63/202] Pulling data for discovered (7656119828...)...
#
# [64/202] Pulling data for discovered (7656119818...)...
#
# [65/202] Pulling data for discovered (7656119885...)...
#
# [66/202] Pulling data for discovered (7656119812...)...
#   Skipped — no game data (private or empty)
#
# [67/202] Pulling data for discovered (7656119804...)...
#   Skipped — no game data (private or empty)
#
# [68/202] Pulling data for discovered (7656119832...)...
#   Skipped — no game data (private or empty)
#
# [69/202] Pulling data for discovered (7656119816...)...
#
# [70/202] Pulling data for discovered (7656119818...)...
#   Skipped — no game data (private or empty)
#
# [71/202] Pulling data for discovered (7656119955...)...
#   Skipped — no game data (private or empty)
#
# [72/202] Pulling data for discovered (7656119820...)...
#   Skipped — no game data (private or empty)
#
# [73/202] Pulling data for discovered (7656119830...)...
#   Skipped — no game data (private or empty)
#
# [74/202] Pulling data for discovered (7656119835...)...
#
# [75/202] Pulling data for discovered (7656119830...)...
#   Skipped — no game data (private or empty)
#
# [76/202] Pulling data for discovered (7656119811...)...
#   Skipped — no game data (private or empty)
#
# [77/202] Pulling data for discovered (7656119829...)...
#   Skipped — no game data (private or empty)
#
# [78/202] Pulling data for discovered (7656119832...)...
#   Skipped — no game data (private or empty)
#
# [79/202] Pulling data for discovered (7656119814...)...
#
# [80/202] Pulling data for discovered (7656119828...)...
#
# [81/202] Pulling data for discovered (7656119834...)...
#
# [82/202] Pulling data for discovered (7656119819...)...
#   Skipped — no game data (private or empty)
#
# [83/202] Pulling data for discovered (7656119819...)...
#
# [84/202] Pulling data for discovered (7656119816...)...
#
# [85/202] Pulling data for discovered (7656119806...)...
#   Skipped — no game data (private or empty)
#
# [86/202] Pulling data for discovered (7656119813...)...
#
# [87/202] Pulling data for discovered (7656119816...)...
#
# [88/202] Pulling data for discovered (7656119884...)...
#   Skipped — no game data (private or empty)
#
# [89/202] Pulling data for discovered (7656119804...)...
#   Skipped — no game data (private or empty)
#
# [90/202] Pulling data for discovered (7656119824...)...
#   Skipped — no game data (private or empty)
#
# [91/202] Pulling data for discovered (7656119837...)...
#   Skipped — no game data (private or empty)
#
# [92/202] Pulling data for discovered (7656119828...)...
#   Skipped — no game data (private or empty)
#
# [93/202] Pulling data for discovered (7656119812...)...
#
# [94/202] Pulling data for discovered (7656119807...)...
#   Skipped — no game data (private or empty)
#
# [95/202] Pulling data for discovered (7656119819...)...
#   Skipped — no game data (private or empty)
#
# [96/202] Pulling data for discovered (7656119828...)...
#   Skipped — no game data (private or empty)
#
# [97/202] Pulling data for discovered (7656119835...)...
#   Skipped — no game data (private or empty)
#
# [98/202] Pulling data for discovered (7656119806...)...
#
# [99/202] Pulling data for discovered (7656119833...)...
#   Skipped — no game data (private or empty)
#
# [100/202] Pulling data for discovered (7656119818...)...
#   Skipped — no game data (private or empty)
#
# [101/202] Pulling data for discovered (7656119819...)...
#   Skipped — no game data (private or empty)
#
# [102/202] Pulling data for discovered (7656119812...)...
#   Skipped — no game data (private or empty)
#
# [103/202] Pulling data for discovered (7656119828...)...
#
# [104/202] Pulling data for discovered (7656119827...)...
#
# [105/202] Pulling data for discovered (7656119883...)...
#   Skipped — no game data (private or empty)
#
# [106/202] Pulling data for discovered (7656119885...)...
#   Skipped — no game data (private or empty)
#
# [107/202] Pulling data for discovered (7656119814...)...
#   Skipped — no game data (private or empty)
#
# [108/202] Pulling data for discovered (7656119820...)...
#
# [109/202] Pulling data for discovered (7656119819...)...
#   Skipped — no game data (private or empty)
#
# [110/202] Pulling data for discovered (7656119827...)...
#   Skipped — no game data (private or empty)
#
# [111/202] Pulling data for discovered (7656119806...)...
#   Skipped — no game data (private or empty)
#
# [112/202] Pulling data for discovered (7656119924...)...
#   Skipped — no game data (private or empty)
#
# [113/202] Pulling data for discovered (7656119816...)...
#   Skipped — no game data (private or empty)
#
# [114/202] Pulling data for discovered (7656119810...)...
#
# [115/202] Pulling data for discovered (7656119834...)...
#   Skipped — no game data (private or empty)
#
# [116/202] Pulling data for discovered (7656119883...)...
#   Skipped — no game data (private or empty)
#
# [117/202] Pulling data for discovered (7656119838...)...
#   Skipped — no game data (private or empty)
#
# [118/202] Pulling data for discovered (7656119814...)...
#
# [119/202] Pulling data for discovered (7656119839...)...
#   Skipped — no game data (private or empty)
#
# [120/202] Pulling data for discovered (7656119806...)...
#   Skipped — no game data (private or empty)
#
# [121/202] Pulling data for discovered (7656119813...)...
#   Skipped — no game data (private or empty)
#
# [122/202] Pulling data for discovered (7656119831...)...
#
# [123/202] Pulling data for discovered (7656119836...)...
#   Skipped — no game data (private or empty)
#
# [124/202] Pulling data for discovered (7656119829...)...
#   Skipped — no game data (private or empty)
#
# [125/202] Pulling data for discovered (7656119811...)...
#   Skipped — no game data (private or empty)
#
# [126/202] Pulling data for discovered (7656119813...)...
#   Skipped — no game data (private or empty)
#
# [127/202] Pulling data for discovered (7656119802...)...
#
# [128/202] Pulling data for discovered (7656119817...)...
#   Skipped — no game data (private or empty)
#
# [129/202] Pulling data for discovered (7656119810...)...
#
# [130/202] Pulling data for discovered (7656119822...)...
#   Skipped — no game data (private or empty)
#
# [131/202] Pulling data for discovered (7656119815...)...
#   Skipped — no game data (private or empty)
#
# [132/202] Pulling data for discovered (7656119833...)...
#   Skipped — no game data (private or empty)
#
# [133/202] Pulling data for discovered (7656119839...)...
#   Skipped — no game data (private or empty)
#
# [134/202] Pulling data for discovered (7656119812...)...
#   Skipped — no game data (private or empty)
#
# [135/202] Pulling data for discovered (7656119815...)...
#   Skipped — no game data (private or empty)
#
# [136/202] Pulling data for discovered (7656119817...)...
#   Skipped — no game data (private or empty)
#
# [137/202] Pulling data for discovered (7656119829...)...
#   Skipped — no game data (private or empty)
#
# [138/202] Pulling data for discovered (7656119817...)...
#   Skipped — no game data (private or empty)
#
# [139/202] Pulling data for discovered (7656119804...)...
#
# [140/202] Pulling data for discovered (7656119823...)...
#   Skipped — no game data (private or empty)
#
# [141/202] Pulling data for discovered (7656119801...)...
#
# [142/202] Pulling data for discovered (7656119883...)...
#
# [143/202] Pulling data for discovered (7656119814...)...
#   Skipped — no game data (private or empty)
#
# [144/202] Pulling data for discovered (7656119824...)...
#   Skipped — no game data (private or empty)
#
# [145/202] Pulling data for discovered (7656119827...)...
#   Skipped — no game data (private or empty)
#
# [146/202] Pulling data for discovered (7656119832...)...
#   Skipped — no game data (private or empty)
#
# [147/202] Pulling data for discovered (7656119813...)...
#   Skipped — no game data (private or empty)
#
# [148/202] Pulling data for discovered (7656119820...)...
#
# [149/202] Pulling data for discovered (7656119821...)...
#   Skipped — no game data (private or empty)
#
# [150/202] Pulling data for discovered (7656119808...)...
# /tmp/ipykernel_45663/3419689697.py:196: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   checkpoint = pd.concat(all_frames, ignore_index=True)
#   ** Checkpoint saved: 5841 rows from 150 users **
#
# [151/202] Pulling data for discovered (7656119824...)...
#   Skipped — no game data (private or empty)
#
# [152/202] Pulling data for discovered (7656119815...)...
#
# [153/202] Pulling data for discovered (7656119813...)...
#   Skipped — no game data (private or empty)
#
# [154/202] Pulling data for discovered (7656119826...)...
#
# [155/202] Pulling data for discovered (7656119839...)...
#   Skipped — no game data (private or empty)
#
# [156/202] Pulling data for discovered (7656119815...)...
#   Skipped — no game data (private or empty)
#
# [157/202] Pulling data for discovered (7656119833...)...
#   Skipped — no game data (private or empty)
#
# [158/202] Pulling data for discovered (7656119812...)...
#
# [159/202] Pulling data for discovered (7656119811...)...
#   Skipped — no game data (private or empty)
#
# [160/202] Pulling data for discovered (7656119830...)...
#
# [161/202] Pulling data for discovered (7656119827...)...
#   Skipped — no game data (private or empty)
#
# [162/202] Pulling data for discovered (7656119827...)...
#   Skipped — no game data (private or empty)
#
# [163/202] Pulling data for discovered (7656119835...)...
#   Skipped — no game data (private or empty)
#
# [164/202] Pulling data for discovered (7656119810...)...
#   Skipped — no game data (private or empty)
#
# [165/202] Pulling data for discovered (7656119805...)...
#   Skipped — no game data (private or empty)
#
# [166/202] Pulling data for discovered (7656119813...)...
#   Skipped — no game data (private or empty)
#
# [167/202] Pulling data for discovered (7656119841...)...
#   Skipped — no game data (private or empty)
#
# [168/202] Pulling data for discovered (7656119811...)...
#
# [169/202] Pulling data for discovered (7656119807...)...
#
# [170/202] Pulling data for discovered (7656119811...)...
#
# [171/202] Pulling data for discovered (7656119804...)...
#   Skipped — no game data (private or empty)
#
# [172/202] Pulling data for discovered (7656119812...)...
#
# [173/202] Pulling data for discovered (7656119884...)...
#
# [174/202] Pulling data for discovered (7656119821...)...
#
# [175/202] Pulling data for discovered (7656119812...)...
# /tmp/ipykernel_45663/3419689697.py:196: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   checkpoint = pd.concat(all_frames, ignore_index=True)
#   ** Checkpoint saved: 7253 rows from 175 users **
#
# [176/202] Pulling data for discovered (7656119815...)...
#
# [177/202] Pulling data for discovered (7656119815...)...
#   Skipped — no game data (private or empty)
#
# [178/202] Pulling data for discovered (7656119805...)...
#
# [179/202] Pulling data for discovered (7656119827...)...
#   Skipped — no game data (private or empty)
#
# [180/202] Pulling data for discovered (7656119817...)...
#
# [181/202] Pulling data for discovered (7656119820...)...
#
# [182/202] Pulling data for discovered (7656119812...)...
#
# [183/202] Pulling data for discovered (7656119796...)...
#
# [184/202] Pulling data for discovered (7656119809...)...
#
# [185/202] Pulling data for discovered (7656119818...)...
#   Skipped — no game data (private or empty)
#
# [186/202] Pulling data for discovered (7656119840...)...
#   Skipped — no game data (private or empty)
#
# [187/202] Pulling data for discovered (7656119820...)...
#
# [188/202] Pulling data for discovered (7656119817...)...
#   Skipped — no game data (private or empty)
#
# [189/202] Pulling data for discovered (7656119882...)...
#
# [190/202] Pulling data for discovered (7656119813...)...
#   Skipped — no game data (private or empty)
#
# [191/202] Pulling data for discovered (7656119811...)...
#
# [192/202] Pulling data for discovered (7656119887...)...
#   Skipped — no game data (private or empty)
#
# [193/202] Pulling data for discovered (7656119838...)...
#
# [194/202] Pulling data for discovered (7656119807...)...
#
# [195/202] Pulling data for discovered (7656119897...)...
#   Skipped — no game data (private or empty)
#
# [196/202] Pulling data for discovered (7656119811...)...
#   Skipped — no game data (private or empty)
#
# [197/202] Pulling data for discovered (7656119838...)...
#   Skipped — no game data (private or empty)
#
# [198/202] Pulling data for discovered (7656119809...)...
#   Skipped — no game data (private or empty)
#
# [199/202] Pulling data for discovered (7656119829...)...
#   Skipped — no game data (private or empty)
#
# [200/202] Pulling data for discovered (7656119828...)...
#   Skipped — no game data (private or empty)
#
# [201/202] Pulling data for discovered (7656119807...)...
#
# [202/202] Pulling data for discovered (7656119817...)...
#   Skipped — no game data (private or empty)
#
# ============================================================
# RAW DATA — NO WRANGLING YET
# ============================================================
# Shape: (9035, 19)
# Columns: ['steamid', 'appid', 'name', 'playtime_hours', 'username', 'country', 'timecreated', 'achievements_completed', 'achievements_total', 'steamspy_name', 'genre', 'tags', 'owners', 'positive_ratings', 'negative_ratings', 'price_usd', 'discount', 'average_playtime', 'label']
# Unique users: 77
# Unique games: 2864
#
# Label distribution:
# label
# discovered    8905
# Matt           117
# Cody            13
#
# Missing values:
# steamid                      0
# appid                        0
# name                         0
# playtime_hours               0
# username                     0
# country                   2130
# timecreated                  0
# achievements_completed    1897
# achievements_total        1897
# steamspy_name                0
# genre                        0
# tags                         0
# owners                       0
# positive_ratings             0
# negative_ratings             0
# price_usd                  331
# discount                   328
# average_playtime             0
# label                        0
# dtype: int64
# /tmp/ipykernel_45663/3419689697.py:201: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(all_frames, ignore_index=True)
# Exported: /content/drive/MyDrive/Data Wrangling Project/steam_v1_raw.csv
#
# ============================================================
# RAW DATA — NO WRANGLING YET
# ============================================================
# Shape: (9035, 19)
# Columns: ['steamid', 'appid', 'name', 'playtime_hours', 'username', 'country', 'timecreated', 'achievements_completed', 'achievements_total', 'steamspy_name', 'genre', 'tags', 'owners', 'positive_ratings', 'negative_ratings', 'price_usd', 'discount', 'average_playtime', 'label']
#
# Dtypes:
# steamid                    object
# appid                       int64
# name                       object
# playtime_hours            float64
# username                   object
# country                    object
# timecreated                 int64
# achievements_completed    float64
# achievements_total        float64
# steamspy_name              object
# genre                      object
# tags                       object
# owners                     object
# positive_ratings            int64
# negative_ratings            int64
# price_usd                 float64
# discount                   object
# average_playtime            int64
# label                      object
# dtype: object
#
# Missing values:
# steamid                      0
# appid                        0
# name                         0
# playtime_hours               0
# username                     0
# country                   2130
# timecreated                  0
# achievements_completed    1897
# achievements_total        1897
# steamspy_name                0
# genre                        0
# tags                         0
# owners                       0
# positive_ratings             0
# negative_ratings             0
# price_usd                  331
# discount                   328
# average_playtime             0
# label                        0
# dtype: int64
#
# First 3 rows:
#              steamid   appid               name  playtime_hours           username country  timecreated  achievements_completed  achievements_total      steamspy_name                                                 genre                                                                                                                                                                                                                                                                                                                                                                                                         tags                    owners  positive_ratings  negative_ratings  price_usd discount  average_playtime label
# 0  76561199121994793  252490               Rust        4.683333  codykihlberg21985    None   1608912819                     NaN                 NaN               Rust  Action, Adventure, Indie, Massively Multiplayer, RPG          {'Survival': 18782, 'Crafting': 11939, 'Multiplayer': 11898, 'Open World': 11339, 'Open World Survival Craft': 8896, 'Building': 8456, 'PvP': 7743, 'Sandbox': 7297, 'Adventure': 5917, 'First-Person': 5414, 'Action': 4960, 'Nudity': 4872, 'FPS': 4808, 'Shooter': 3944, 'Co-op': 3871, 'Online Co-Op': 3821, 'Indie': 3125, 'Post-apocalyptic': 3016, 'Early Access': 2931, 'Simulation': 2638}  20,000,000 .. 50,000,000           1071135            156649      39.99        0                 0  Cody
# 1  76561199121994793  394360  Hearts of Iron IV      137.883333  codykihlberg21985    None   1608912819                     NaN                 NaN  Hearts of Iron IV                                  Simulation, Strategy       {'Strategy': 3591, 'World War II': 2809, 'Grand Strategy': 2693, 'War': 2405, 'Historical': 2355, 'Military': 2110, 'Alternate History': 1799, 'Multiplayer': 1596, 'Simulation': 1367, 'Tactical': 1319, 'Singleplayer': 1185, 'Real-Time with Pause': 1181, 'RTS': 1153, 'Diplomacy': 1078, 'Sandbox': 881, 'Co-op': 778, 'Strategy RPG': 676, 'Open World': 658, 'Competitive': 654, 'Action': 622}   5,000,000 .. 10,000,000            305168             36982      49.99        0                 0  Cody
# 2  76561199121994793  892970            Valheim       56.650000  codykihlberg21985    None   1608912819                     NaN                 NaN            Valheim           Action, Adventure, Indie, RPG, Early Access  {'Open World Survival Craft': 2379, 'Survival': 2252, 'Online Co-Op': 2174, 'Open World': 2083, 'Multiplayer': 2027, 'Building': 1854, 'Crafting': 1713, 'Base-Building': 1612, 'Exploration': 1574, 'Co-op': 1454, 'Adventure': 1264, 'Difficult': 1251, 'Mythology': 1234, 'Sandbox': 1220, 'PvE': 1194, 'Third Person': 1191, 'Action': 1184, 'Singleplayer': 1182, 'Early Access': 1165, 'Indie': 1159}  10,000,000 .. 20,000,000            471451             28377      19.99        0                 0  Cody
#
# Exported: steam_v1_raw.csv

# %%
# Keeps script running while it pulls data
# %%javascript
function ClickConnect(){
    console.log("Keeping Colab alive...");
    document.querySelector("colab-connect-button").click()
}
setInterval(ClickConnect, 60000)

# %%
# WRANGLING v2: TYPE CONVERSION + DATE PARSING
master_df = pd.read_csv(f"{output_dir}steam_v1_raw.csv")
print(f"Loaded raw data: {master_df.shape}")


# TYPE CONVERSION
print("\n--- Type Conversion ---")

master_df["playtime_hours"] = master_df["playtime_hours"].astype(float)
master_df["achievements_completed"] = master_df["achievements_completed"].fillna(0).astype(int)
master_df["achievements_total"] = master_df["achievements_total"].fillna(0).astype(int)
master_df["positive_ratings"] = pd.to_numeric(master_df["positive_ratings"], errors="coerce").fillna(0).astype(int)
master_df["negative_ratings"] = pd.to_numeric(master_df["negative_ratings"], errors="coerce").fillna(0).astype(int)
master_df["price_usd"] = pd.to_numeric(master_df["price_usd"], errors="coerce").fillna(0).astype(float)
master_df["discount"] = pd.to_numeric(master_df["discount"], errors="coerce").fillna(0).astype(int)

if "average_playtime" in master_df.columns:
    master_df["average_playtime_hours"] = pd.to_numeric(master_df["average_playtime"], errors="coerce").fillna(0) / 60
    master_df = master_df.drop(columns=["average_playtime"])

print(f"Dtypes after conversion:\n{master_df.dtypes}")


# DATE PARSING
print("\n--- Date Parsing ---")

master_df["account_created"] = pd.to_datetime(master_df["timecreated"], unit="s", errors="coerce")
master_df["account_age_years"] = (pd.Timestamp.now() - master_df["account_created"]).dt.days / 365.25
master_df = master_df.drop(columns=["timecreated"])

print(master_df[["steamid", "username", "account_created", "account_age_years"]].drop_duplicates().to_string(index=False))

print(f"\nShape: {master_df.shape}")
master_df.to_csv(f"{output_dir}steam_v2_typed.csv", index=False)
print("Exported: steam_v2_typed.csv")
# Out:
# Loaded raw data: (9035, 19)
#
# --- Type Conversion ---
# Dtypes after conversion:
# steamid                     int64
# appid                       int64
# name                       object
# playtime_hours            float64
# username                   object
# country                    object
# timecreated                 int64
# achievements_completed      int64
# achievements_total          int64
# steamspy_name              object
# genre                      object
# tags                       object
# owners                     object
# positive_ratings            int64
# negative_ratings            int64
# price_usd                 float64
# discount                    int64
# label                      object
# average_playtime_hours    float64
# dtype: object
#
# --- Date Parsing ---
#           steamid                         username     account_created  account_age_years
# 76561199121994793                codykihlberg21985 2020-12-25 16:13:39           5.311431
# 76561198244049512                            oMatt 2015-08-10 22:42:42          10.688569
# 76561198799289551                    GimpShrimpToo 2017-12-25 20:04:15           8.312115
# 76561198154247566                       ninja real 2014-09-12 21:26:58          11.597536
# 76561198275365957                         TahmNook 2016-01-08 03:41:54          10.275154
# 76561198255755713                     Moist Orphan 2015-10-17 19:04:55          10.502396
# 76561198148018674                          Grandpa 2014-08-01 22:56:05          11.712526
# 76561198103480618                            Yurva 2013-08-18 19:11:12          12.665298
# 76561199435368759                             Fury 2022-11-16 03:57:22           3.419576
# 76561199027530720                76561199027530720 2020-02-18 16:21:52           6.162902
# 76561198081488553                          Mr. M16 2013-01-15 22:13:42          13.253936
# 76561198277811435                         NovaCore 2016-01-20 00:16:04          10.242300
# 76561198202083709                           Yellow 2015-06-17 00:14:58          10.836413
# 76561198060479184                          Houmr96 2012-03-17 14:34:27          14.086242
# 76561198079411573                      SlayerSloth 2012-12-25 17:14:32          13.311431
# 76561199469542990                76561199469542990 2023-01-12 13:24:28           3.263518
# 76561198289400944                         Beanzoup 2016-03-07 21:37:30          10.113621
# 76561198026252696                       Madhatterz 2010-06-04 01:19:10          15.871321
# 76561198026700770                       Pmaniscool 2010-06-17 00:55:44          15.835729
# 76561198152578529                           UpIsUp 2014-09-01 04:22:20          11.627652
# 76561198120756503                             Dave 2013-12-28 16:56:30          12.303901
# 76561198090815834                76561198090815834 2013-05-07 16:28:11          12.947296
# 76561198155861650                          Big Ben 2014-09-25 00:34:10          11.561944
# 76561198255462351                     Mr. Vanishya 2015-10-16 00:56:12          10.505133
# 76561198297861311                       zackattack 2016-04-09 18:34:48          10.023272
# 76561198170087545                             chad 2014-12-25 17:00:00          11.312799
# 76561198289838016                   Brian O'Conner 2016-03-12 18:35:52          10.099932
# 76561198186464846                Sailorsavedme. ⚓🕷 2015-03-19 23:57:36          11.080082
# 76561198854102771                            Ersid 2018-08-16 10:48:27           7.671458
# 76561198166367987                   TUNNELTROLL119 2014-12-03 17:24:14          11.373032
# 76561198354507651                          Peacock 2016-12-26 19:38:50           9.308693
# 76561198146200248                       Maxpatriot 2014-07-22 16:12:18          11.739904
# 76561198289025426                   A Neutered Dog 2016-03-06 09:54:51          10.116359
# 76561198349989338                          Rodrick 2016-12-11 20:48:42           9.349760
# 76561198198661478                    Aлeвтинкa>♥♥♥ 2015-05-28 14:30:55          10.891170
# 76561198165787560                   NotCrunchyCrew 2014-11-29 17:40:17          11.383984
# 76561198133996753 LiFeLiNe!!! LIFE-LINE!! REZ MEE! 2014-04-21 01:52:18          11.991786
# 76561198168000861                  KITHtheBRAND123 2014-12-14 19:43:19          11.342916
# 76561198122625785                           connor 2014-01-11 23:29:26          12.262834
# 76561198063224128                             Jopy 2012-05-07 05:26:56          13.946612
# 76561198288237728                         im Ready 2016-03-05 19:46:58          10.119097
# 76561198276361235                   Armpit Sniffer 2016-01-13 06:15:03          10.261465
# 76561198201415143                            weeed 2015-06-13 18:04:39          10.847365
# 76561198104796074                            Xanny 2013-08-27 23:03:46          12.640657
# 76561198145483915                           Otepse 2014-07-18 09:07:45          11.750856
# 76561198310540360                        Fabivilla 2016-06-14 18:17:49           9.842574
# 76561198028523395                        Unleashed 2010-08-04 10:49:27          15.704312
# 76561198104048612                     AssAssin7998 2013-08-23 00:19:42          12.651608
# 76561198041373066                            Holly 2011-05-01 15:19:31          14.965092
# 76561198016430875                        Bandiwyn🍃 2009-11-19 01:13:58          16.410678
# 76561198833263975                            Vamsi 2018-04-29 18:51:07           7.969884
# 76561198201231869                      MooslimPork 2015-06-13 01:29:54          10.847365
# 76561198089500543              Galexander Gambrell 2013-04-21 18:34:53          12.991102
# 76561198151248223                   brutal  sniper 2014-08-22 21:29:14          11.655031
# 76561198262765417                            Nicky 2015-11-27 20:08:01          10.390144
# 76561198124316870                             aral 2014-01-26 07:54:07          12.224504
# 76561198306571127                      King Dedede 2016-05-22 15:46:11           9.905544
# 76561198113232430                           Hopbag 2013-11-02 22:00:59          12.457221
# 76561198079507365                         Mr.Mario 2012-12-25 19:02:07          13.311431
# 76561198110814170                     AlmondWallie 2013-10-13 20:27:35          12.511978
# 76561198126151021                            M1nty 2014-02-11 01:17:43          12.180698
# 76561198848689636                            -s44d 2018-07-19 01:00:29           7.748118
# 76561198218936197                             woly 2015-09-19 17:00:38          10.579055
# 76561198120366128                       TreeSpoons 2013-12-26 20:29:33          12.309377
# 76561198157944151                     6oxingtiger🐯 2014-10-09 23:39:43          11.520876
# 76561198050595483              twitch.tv/nudleiwnl 2011-10-15 19:01:03          14.507871
# 76561198176955138                         Forehead 2015-01-31 23:30:51          11.208761
# 76561198209313193                       MP3 Dealer 2015-07-27 19:59:29          10.726899
# 76561198122480238                         Djrook44 2014-01-10 14:18:04          12.268309
# 76561197967747343                              Yar 2004-07-27 22:42:20          21.724846
# 76561198097790321                          Doritos 2013-07-13 11:54:48          12.763860
# 76561198201086159                     Kingoliver42 2015-06-11 19:49:35          10.852841
# 76561198823700287                        30tyznxwh 2018-03-19 09:01:21           8.082136
# 76561198119438924                             hazz 2013-12-25 11:22:31          12.312115
# 76561198384004412  Baby Gronk (I smoke cigarettes) 2017-04-28 22:54:50           8.971937
# 76561198072102288              little cow that moo 2012-09-21 22:50:12          13.571526
# 76561198073158798             DivorcedAndHopeless9 2012-10-08 00:39:04          13.524983
#
# Shape: (9035, 20)
# Exported: steam_v2_typed.csv

# %%
# WRANGLING v3: REGEX + TEXT CLEANING

import re
master_df = pd.read_csv(f"{output_dir}steam_v2_typed.csv")
print(f"Loaded typed data: {master_df.shape}")


# REGEX — Extract lower bound from owners range string

print("\n--- Regex ---")
master_df["owners_lower"] = (
    master_df["owners"]
    .astype(str)
    .str.replace(",", "", regex=False)
    .str.extract(r"(\d+)")
    .astype(float)
)
print("Sample owners parsing:")
print(master_df[["owners", "owners_lower"]].drop_duplicates().head(5).to_string(index=False))

master_df = master_df.drop(columns=["owners"])

# TEXT CLEANING — Clean game names, flatten tags, fill nulls

print("\n--- Text Cleaning ---")
master_df["name"] = (
    master_df["name"]
    .astype(str)
    .str.strip()
    .str.replace(r"[™®©]", "", regex=True)
    .str.replace(r"\s+", " ", regex=True)
)

def flatten_tags(tags):
    if isinstance(tags, str) and tags.startswith("{"):
        try:
            tags_dict = eval(tags)
            if isinstance(tags_dict, dict):
                return ", ".join(list(tags_dict.keys())[:3])
        except:
            pass
    if isinstance(tags, dict):
        return ", ".join(list(tags.keys())[:3])
    return "Unknown"

master_df["top_tags"] = master_df["tags"].apply(flatten_tags)
master_df = master_df.drop(columns=["tags"])

master_df["country"] = master_df["country"].fillna("Unknown")
master_df["genre"] = master_df["genre"].fillna("Unknown")

print(f"Sample cleaned names: {master_df['name'].head(5).tolist()}")
print(f"Sample tags: {master_df['top_tags'].head(5).tolist()}")

print(f"\nShape: {master_df.shape}")
master_df.to_csv(f"{output_dir}steam_v3_cleaned.csv", index=False)
print("Exported: steam_v3_cleaned.csv")
# Out:
# Loaded typed data: (9035, 20)
#
# --- Regex ---
# Sample owners parsing:
#                   owners  owners_lower
# 20,000,000 .. 50,000,000    20000000.0
#  5,000,000 .. 10,000,000     5000000.0
# 10,000,000 .. 20,000,000    10000000.0
#   2,000,000 .. 5,000,000     2000000.0
#       100,000 .. 200,000      100000.0
#
# --- Text Cleaning ---
# Sample cleaned names: ['Rust', 'Hearts of Iron IV', 'Valheim', 'Total War: WARHAMMER III', 'Sea of Thieves']
# Sample tags: ['Survival, Crafting, Multiplayer', 'Strategy, World War II, Grand Strategy', 'Open World Survival Craft, Survival, Online Co-Op', 'Strategy, Turn-Based Strategy, Grand Strategy', 'Multiplayer, Open World, Adventure']
#
# Shape: (9035, 20)
# Exported: steam_v3_cleaned.csv

# %%
# WRANGLING v4: FUZZY MATCHING + DEDUPLICATION

# !pip install thefuzz python-Levenshtein -q
from thefuzz import fuzz

master_df = pd.read_csv(f"{output_dir}steam_v3_cleaned.csv")
print(f"Loaded cleaned data: {master_df.shape}")


# FUZZY MATCHING — Compare Steam API name vs SteamSpy name

print("\n--- Fuzzy Matching ---")
master_df["name_match_score"] = master_df.apply(
    lambda row: fuzz.ratio(str(row["name"]), str(row["steamspy_name"]))
    if pd.notna(row["name"]) and pd.notna(row["steamspy_name"])
    else None,
    axis=1
)

mismatches = master_df[master_df["name_match_score"] < 90][
    ["appid", "name", "steamspy_name", "name_match_score"]
].drop_duplicates()

if len(mismatches) > 0:
    print(f"Found {len(mismatches)} name mismatches (score < 90):")
    print(mismatches.head(10).to_string(index=False))
else:
    print("All game names match between Steam API and SteamSpy (score >= 90)")

master_df = master_df.rename(columns={"name": "game_name"})
master_df = master_df.drop(columns=["steamspy_name"])

# DEDUPLICATION — Remove duplicate user+game rows

print("\n--- Deduplication ---")
before = len(master_df)
master_df = master_df.drop_duplicates(subset=["steamid", "appid"])
after = len(master_df)
print(f"Rows before: {before} | After: {after} | Removed: {before - after}")

print(f"\nShape: {master_df.shape}")
master_df.to_csv(f"{output_dir}steam_v4_deduped.csv", index=False)
print("Exported: steam_v4_deduped.csv")
# Out:
# Loaded cleaned data: (9035, 20)
#
# --- Fuzzy Matching ---
# Found 207 name mismatches (score < 90):
#   appid                                     name                            steamspy_name  name_match_score
# 1172620                           Sea of Thieves             Sea of Thieves: 2026 Edition              67.0
# 1938090                             Call of Duty          Call of Duty: Modern Warfare II              56.0
#     730                         Counter-Strike 2         Counter-Strike: Global Offensive              62.0
#    3590     Plants vs. Zombies: Game of the Year          Plants vs. Zombies GOTY Edition              66.0
#    6060 Star Wars: Battlefront 2 (Classic, 2005) STAR WARS Battlefront II (Classic, 2005)              80.0
#  495420                         State of Decay 2     State of Decay 2: Juggernaut Edition              62.0
#  555160                                Pavlov VR                                   Pavlov              80.0
#  562810                            Monopoly Plus                            MONOPOLY PLUS              23.0
# 1097150                                Fall Guys             Fall Guys: Ultimate Knockout              49.0
#   34900                                 Bad Rats              Bad Rats: the Rats' Revenge              46.0
#
# --- Deduplication ---
# Rows before: 9035 | After: 9035 | Removed: 0
#
# Shape: (9035, 20)
# Exported: steam_v4_deduped.csv

# %%
# WRANGLING v5: RESHAPING + TIDYING + FINAL EXPORT


master_df = pd.read_csv(f"{output_dir}steam_v4_deduped.csv")
print(f"Loaded deduped data: {master_df.shape}")

# RESHAPING — Explode comma-separated genres into long format

print("\n--- Reshaping ---")
master_df["genre_list"] = master_df["genre"].str.split(", ")
genres_long = master_df.explode("genre_list")
genres_long = genres_long.rename(columns={"genre_list": "single_genre"})

print(f"Master df shape (wide): {master_df.shape}")
print(f"Genres long shape (exploded): {genres_long.shape}")
print(f"Unique genres found: {genres_long['single_genre'].nunique()}")
print(f"\nGenre counts:")
print(genres_long["single_genre"].value_counts().head(10).to_string())


# TIDYING — Create a normalized genre lookup table

print("\n--- Tidying ---")
genre_lookup = (
    genres_long[["appid", "game_name", "single_genre"]]
    .drop_duplicates()
    .reset_index(drop=True)
)

print(f"Genre lookup table: {genre_lookup.shape[0]} rows (one row = one game-genre pair)")
print(genre_lookup.head(10).to_string(index=False))

master_df = master_df.drop(columns=["genre_list"])


# FINAL CLEANUP & EXPORT

master_df = master_df.reset_index(drop=True)

print(f"\n{'='*60}")
print(f"FINAL MASTER DATAFRAME")
print(f"{'='*60}")
print(f"Shape: {master_df.shape}")
print(f"Columns: {list(master_df.columns)}")
print(f"\nMissing values:\n{master_df.isnull().sum()}")
print(f"\nDtypes:\n{master_df.dtypes}")
print(f"\nFirst 5 rows:")
print(master_df.head().to_string())

master_df.to_csv(f"{output_dir}steam_v5_final.csv", index=False)
genre_lookup.to_csv(f"{output_dir}steam_genre_lookup.csv", index=False)
genres_long.to_csv(f"{output_dir}steam_genres_long.csv", index=False)

print("\nExported:")
print(f"  {output_dir}steam_v5_final.csv")
print(f"  {output_dir}steam_genre_lookup.csv")
print(f"  {output_dir}steam_genres_long.csv")
# Out:
# Loaded deduped data: (9035, 20)
#
# --- Reshaping ---
# Master df shape (wide): (9035, 21)
# Genres long shape (exploded): (25125, 21)
# Unique genres found: 28
#
# Genre counts:
# single_genre
# Action                   6129
# Indie                    3908
# Adventure                3033
# RPG                      1876
# Simulation               1847
# Free To Play             1843
# Strategy                 1598
# Casual                   1580
# Massively Multiplayer    1104
# Early Access              612
#
# --- Tidying ---
# Genre lookup table: 7783 rows (one row = one game-genre pair)
#  appid         game_name          single_genre
# 252490              Rust                Action
# 252490              Rust             Adventure
# 252490              Rust                 Indie
# 252490              Rust Massively Multiplayer
# 252490              Rust                   RPG
# 394360 Hearts of Iron IV            Simulation
# 394360 Hearts of Iron IV              Strategy
# 892970           Valheim                Action
# 892970           Valheim             Adventure
# 892970           Valheim                 Indie
#
# ============================================================
# FINAL MASTER DATAFRAME
# ============================================================
# Shape: (9035, 20)
# Columns: ['steamid', 'appid', 'game_name', 'playtime_hours', 'username', 'country', 'achievements_completed', 'achievements_total', 'genre', 'positive_ratings', 'negative_ratings', 'price_usd', 'discount', 'label', 'average_playtime_hours', 'account_created', 'account_age_years', 'owners_lower', 'top_tags', 'name_match_score']
#
# Missing values:
# steamid                    0
# appid                      0
# game_name                  0
# playtime_hours             0
# username                   0
# country                    0
# achievements_completed     0
# achievements_total         0
# genre                      0
# positive_ratings           0
# negative_ratings           0
# price_usd                  0
# discount                   0
# label                      0
# average_playtime_hours     0
# account_created            0
# account_age_years          0
# owners_lower               0
# top_tags                   0
# name_match_score          26
# dtype: int64
#
# Dtypes:
# steamid                     int64
# appid                       int64
# game_name                  object
# playtime_hours            float64
# username                   object
# country                    object
# achievements_completed      int64
# achievements_total          int64
# genre                      object
# positive_ratings            int64
# negative_ratings            int64
# price_usd                 float64
# discount                    int64
# label                      object
# average_playtime_hours    float64
# account_created            object
# account_age_years         float64
# owners_lower              float64
# top_tags                   object
# name_match_score          float64
# dtype: object
#
# First 5 rows:
#              steamid    appid                 game_name  playtime_hours           username  country  achievements_completed  achievements_total                                                 genre  positive_ratings  negative_ratings  price_usd  discount label  average_playtime_hours      account_created  account_age_years  owners_lower                                           top_tags  name_match_score
# 0  76561199121994793   252490                      Rust        4.683333  codykihlberg21985  Unknown                       0                   0  Action, Adventure, Indie, Massively Multiplayer, RPG           1071135            156649      39.99         0  Cody                     0.0  2020-12-25 16:13:39           5.311431    20000000.0                    Survival, Crafting, Multiplayer             100.0
# 1  76561199121994793   394360         Hearts of Iron IV      137.883333  codykihlberg21985  Unknown                       0                   0                                  Simulation, Strategy            305168             36982      49.99         0  Cody                     0.0  2020-12-25 16:13:39           5.311431     5000000.0             Strategy, World War II, Grand Strategy             100.0
# 2  76561199121994793   892970                   Valheim       56.650000  codykihlberg21985  Unknown                       0                   0           Action, Adventure, Indie, RPG, Early Access            471451             28377      19.99         0  Cody                     0.0  2020-12-25 16:13:39           5.311431    10000000.0  Open World Survival Craft, Survival, Online Co-Op             100.0
# 3  76561199121994793  1142710  Total War: WARHAMMER III        7.516667  codykihlberg21985  Unknown                       0                   0                                      Action, Strategy             87141             32717      14.99        75  Cody                     0.0  2020-12-25 16:13:39           5.311431     2000000.0      Strategy, Turn-Based Strategy, Grand Strategy             100.0
# 4  76561199121994793  1172620            Sea of Thieves       11.816667  codykihlberg21985  Unknown                       0                   0                                     Action, Adventure            317074             38164      19.99        50  Cody                     0.0  2020-12-25 16:13:39           5.311431     5000000.0                 Multiplayer, Open World, Adventure              67.0
#
# Exported:
#   /content/drive/MyDrive/Data Wrangling Project/steam_v5_final.csv
#   /content/drive/MyDrive/Data Wrangling Project/steam_genre_lookup.csv
#   /content/drive/MyDrive/Data Wrangling Project/steam_genres_long.csv
